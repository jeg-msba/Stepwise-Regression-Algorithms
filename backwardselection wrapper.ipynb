# %%
import pandas as pd
import backward_selection as bs

# %% [markdown]
# In order to create a first order linear model I will perform a forward selection stepwise linear regression. This means I will create a simple linear model for each variable individually. I will take the model whose variable has  the smallest t-test p-value and put that variable in my model. I will then create two variable models using my first selected variable and add each of the remaining variables. I then pick the second variable from the model with the lowest p-value. This will process continue until the R-squared adjusted value stops increasing or I run out of variables. yhat is the dependent variable, GNI. xvars are all the independent variables. modelVars are the independent variables selected for the model.

# %%
yhat = pd.read_csv('/work/yhat.csv', index_col=0)
xvars = pd.read_csv('/work/xvars.csv', index_col=0)
model, modelVars = bs.backward_selection(yhat, xvars, alpha=.10)

# %%
xvars
# Out:
#      Deaths from high systolic blood pressure  \
# 0                                   95.360465
# 2                                  266.597835
# 50                                 137.222988
# 1                                   54.663801
# 6                                  276.158150
# ..                                        ...
# 184                                195.884910
# 183                                165.359032
# 142                                 81.446042
# 187                                 56.257104
# 188                                 79.721911
#
#      Deaths from diet high in sodium  Deaths from diet low in whole grains  \
# 0                           3.764500                             27.362995
# 2                          85.652365                             53.247628
# 50                          4.472115                             34.590452
# 1                           3.983202                              6.221797
# 6                          37.644677                             86.713180
# ..                               ...                                   ...
# 184                        28.368931                             33.838281
# 183                        33.572669                             12.440090
# 142                         3.044381                             25.207976
# 187                         9.944044                              4.748298
# 188                         7.426931                              9.606680
#
#      Deaths from alcohol use  Deaths from diet low in fruits  \
# 0                   1.543651                       12.134087
# 2                  25.810177                        7.608351
# 50                  3.008927                        6.201714
# 1                  36.798939                        4.881277
# 6                  28.418969                       11.318605
# ..                       ...                             ...
# 184                15.012901                       17.517700
# 183                55.320673                       15.803480
# 142                 4.682947                        7.030915
# 187                37.375145                       11.184384
# 188                33.578122                       12.764026
#
#      Deaths from unsafe water source  Deaths from secondhand smoke  \
# 0                           9.930514                     16.048859
# 2                           0.132441                     27.108000
# 50                          0.648624                     17.961234
# 1                          34.442783                      5.051483
# 6                           0.098856                     35.671857
# ..                               ...                           ...
# 184                        18.351522                     20.873119
# 183                         1.305739                     19.926985
# 142                         0.456038                     13.132045
# 187                        32.181001                      5.000161
# 188                        25.491122                     10.719753
#
#      Deaths from low birth weight  Deaths from child wasting  \
# 0                       58.598845                  32.525645
# 2                        3.708008                   1.165086
# 50                      16.606361                   1.744341
# 1                       49.071154                  33.276553
# 6                        4.723859                   1.653864
# ..                            ...                        ...
# 184                     18.567851                  11.872581
# 183                      5.519519                   1.604762
# 142                     13.386555                   0.959294
# 187                     45.078547                  34.622336
# 188                     51.752688                  37.780778
#
#      Deaths from unsafe sex  ...  Deaths from drug use  \
# 0                  1.962450  ...              1.853106
# 2                  2.315452  ...              4.543624
# 50                 2.191260  ...              2.412677
# 1                 50.637818  ...              1.722390
# 6                  6.090020  ...              3.398442
# ..                      ...  ...                   ...
# 184                9.509985  ...              5.492999
# 183                7.852616  ...             10.028645
# 142                0.884501  ...              1.032360
# 187              106.535266  ...              2.143952
# 188              123.903013  ...              6.269863
#
#      Deaths from low bone mineral density  Deaths from vitamin a deficiency  \
# 0                                1.672021                          1.039825
# 2                                2.273802                          0.003525
# 50                               3.213319                          0.006538
# 1                                2.219240                          0.997312
# 6                                2.291218                          0.000178
# ..                                    ...                               ...
# 184                              2.463427                          0.390362
# 183                              8.759758                          0.006975
# 142                              1.279711                          0.007593
# 187                              2.164440                          0.613193
# 188                              2.851834                          0.530021
#
#      Deaths from child stunting  Deaths from non-exclusive breastfeeding  \
# 0                      8.132029                                 4.667007
# 2                      0.334040                                 0.136510
# 50                     0.159600                                 0.341260
# 1                      5.638167                                 5.192737
# 6                      0.261560                                 0.334997
# ..                          ...                                      ...
# 184                    1.586004                                 1.279391
# 183                    0.249122                                 0.257032
# 142                    0.078501                                 0.146165
# 187                    5.922420                                 4.020375
# 188                    3.812492                                 4.107905
#
#      Deaths from iron deficiency  \
# 0                       2.015966
# 2                       0.013358
# 50                      0.219995
# 1                       1.207919
# 6                       0.038493
# ..                           ...
# 184                     0.536316
# 183                     0.030945
# 142                     0.057997
# 187                     0.964998
# 188                     1.686791
#
#      Deaths from ambient particulate matter pollution  \
# 0                                           22.978015
# 2                                           53.690979
# 50                                          50.610364
# 1                                           17.193698
# 6                                          109.572283
# ..                                                ...
# 184                                         17.880854
# 183                                         39.108367
# 142                                         38.241033
# 187                                         16.042280
# 188                                         16.978780
#
#      Deaths from low physical activity  \
# 0                            10.900777
# 2                            10.858755
# 50                           22.432433
# 1                             2.460511
# 6                            21.118826
# ..                                 ...
# 184                           7.776103
# 183                           5.801354
# 142                          15.318193
# 187                           1.789766
# 188                           2.244214
#
#      Deaths from no access to handwashing facility  \
# 0                                        10.435293
# 2                                         0.284609
# 50                                        0.763036
# 1                                        21.664316
# 6                                         0.760939
# ..                                             ...
# 184                                       7.180887
# 183                                       2.143887
# 142                                       0.834706
# 187                                      21.627404
# 188                                      26.787520
#
#      Deaths from high ldl cholesterol
# 0                           52.280249
# 2                           97.772076
# 50                          64.474379
# 1                           12.251989
# 6                          122.493000
# ..                                ...
# 184                         80.138270
# 183                         42.393295
# 142                         44.986769
# 187                         11.491900
# 188                         23.259163
#
# [98 rows x 28 columns]

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     GNI per Capita 2019   R-squared:                       0.725
# Model:                             OLS   Adj. R-squared:                  0.693
# Method:                  Least Squares   F-statistic:                     22.88
# Date:                 Wed, 10 Jan 2024   Prob (F-statistic):           2.34e-20
# Time:                         20:39:09   Log-Likelihood:                -810.89
# No. Observations:                   98   AIC:                             1644.
# Df Residuals:                       87   BIC:                             1672.
# Df Model:                           10
# Covariance Type:             nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                 2779.5234    414.137      6.712      0.000    1956.381    3602.666
# Deaths from household air pollution from solid fuels   186.2557    110.659      1.683      0.096     -33.690     406.202
# Deaths from smoking                                     13.1306      4.620      2.842      0.006       3.948      22.314
# Deaths from air pollution                             -209.9123    109.751     -1.913      0.059    -428.054       8.229
# Deaths from high body-mass index                        16.4714      3.940      4.181      0.000       8.640      24.302
# Deaths from drug use                                   -76.6467     36.949     -2.074      0.041    -150.087      -3.206
# Deaths from low bone mineral density                   271.1500     81.659      3.321      0.001     108.844     433.456
# Deaths from non-exclusive breastfeeding                141.9886     43.897      3.235      0.002      54.738     229.240
# Deaths from ambient particulate matter pollution       200.6169    113.796      1.763      0.081     -25.565     426.799
# Deaths from no access to handwashing facility          -55.5390     17.377     -3.196      0.002     -90.079     -20.999
# Deaths from high ldl cholesterol                       -13.8601      4.235     -3.273      0.002     -22.278      -5.442
# ==============================================================================
# Omnibus:                        1.771   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.413   Jarque-Bera (JB):                1.359
# Skew:                           0.281   Prob(JB):                        0.507
# Kurtosis:                       3.128   Cond. No.                         710.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
modelVars
# Out:
#      Deaths from household air pollution from solid fuels  \
# 0                                            74.579798
# 2                                            25.375896
# 50                                            0.155228
# 1                                            26.969615
# 6                                             2.781399
# ..                                                 ...
# 184                                         118.654173
# 183                                          34.712647
# 142                                           0.605916
# 187                                          47.996464
# 188                                          65.249018
#
#      Deaths from smoking  Deaths from air pollution  \
# 0              27.286221                  98.050175
# 2             155.025435                  79.751719
# 50             50.474622                  51.894991
# 1              23.213833                  44.459805
# 6             172.461315                 116.543334
# ..                   ...                        ...
# 184            81.158858                 136.648921
# 183           101.353976                  74.862684
# 142            46.644130                  39.435977
# 187            25.426002                  64.342247
# 188            57.560877                  82.495978
#
#      Deaths from high body-mass index  Deaths from drug use  \
# 0                           58.375394              1.853106
# 2                          109.303897              4.543624
# 50                          84.503194              2.412677
# 1                           21.576950              1.722390
# 6                          158.236008              3.398442
# ..                                ...                   ...
# 184                        109.476032              5.492999
# 183                         39.655285             10.028645
# 142                         60.095857              1.032360
# 187                         33.044788              2.143952
# 188                         42.172569              6.269863
#
#      Deaths from low bone mineral density  \
# 0                                1.672021
# 2                                2.273802
# 50                               3.213319
# 1                                2.219240
# 6                                2.291218
# ..                                    ...
# 184                              2.463427
# 183                              8.759758
# 142                              1.279711
# 187                              2.164440
# 188                              2.851834
#
#      Deaths from non-exclusive breastfeeding  \
# 0                                   4.667007
# 2                                   0.136510
# 50                                  0.341260
# 1                                   5.192737
# 6                                   0.334997
# ..                                       ...
# 184                                 1.279391
# 183                                 0.257032
# 142                                 0.146165
# 187                                 4.020375
# 188                                 4.107905
#
#      Deaths from ambient particulate matter pollution  \
# 0                                           22.978015
# 2                                           53.690979
# 50                                          50.610364
# 1                                           17.193698
# 6                                          109.572283
# ..                                                ...
# 184                                         17.880854
# 183                                         39.108367
# 142                                         38.241033
# 187                                         16.042280
# 188                                         16.978780
#
#      Deaths from no access to handwashing facility  \
# 0                                        10.435293
# 2                                         0.284609
# 50                                        0.763036
# 1                                        21.664316
# 6                                         0.760939
# ..                                             ...
# 184                                       7.180887
# 183                                       2.143887
# 142                                       0.834706
# 187                                      21.627404
# 188                                      26.787520
#
#      Deaths from high ldl cholesterol
# 0                           52.280249
# 2                           97.772076
# 50                          64.474379
# 1                           12.251989
# 6                          122.493000
# ..                                ...
# 184                         80.138270
# 183                         42.393295
# 142                         44.986769
# 187                         11.491900
# 188                         23.259163
#
# [98 rows x 10 columns]

# %% [markdown]
# I used nested for loops. The inner loop created a model with every remaining available variable. The outer loop picks the variable with the lowest p-value and adds it to the model. The variable is then removed from the list of remaining variables The outer loop stops when the R squared adjust value stops increasing. The R-squared adjusted value tells us the  proportion of variance in the dependent variable (GNI) that can be explained by the independent variables (risk). The higher the score the better. A score of one means the model perfectly predicts each dependent variable data point.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=afeacf8c-bdd6-4dc6-a7d0-d44661b39e0f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
